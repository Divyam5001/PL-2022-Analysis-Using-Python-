# %%
#LOading the requid Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
#importing data
data = pd.read_csv('IPL_2022.csv')

# %%
#checking data row and columns
data.shape
# Out:
# (74, 20)

# %%
#checking all columns
print(list(data.columns))
# Out:
# ['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner', 'toss_decision', 'first_ings_score', 'first_ings_wkts', 'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by', 'margin', 'player_of_the_match', 'top_scorer', 'highscore', 'best_bowling', 'best_bowling_figure']

# %%
# First 5 records
data.head(5)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
# Most man of the match award
data['player_of_the_match'].value_counts()
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Umesh Yadav          2
# Quinton de Kock      2
# David Miller         2
# Umran Malik          2
# K L Rahul            2
# Rahul Tripathi       2
# Hardik Pandya        2
# Jasprit Bumrah       2
# Shubman Gill         2
# Yuzvendra Chahal     2
# Wanindu Hasaranga    2
# Avesh Khan           2
# Dinesh Karthik       2
# Virat Kohli          1
# Rinku Singh          1
# Kagiso Rabada        1
# Harshal Patel        1
# David Warner         1
# Harpreet Brar        1
# Tim David            1
# Yashasvi Jaiswal     1
# R Aswin              1
# Andre Russell        1
# Shardul Thakur       1
# Trent Boult          1
# Devon Conway         1
# W. Saha              1
# Mitchell Marsh       1
# Mohsin Khan          1
# Daniel Sams          1
# Jonny Bairstow       1
# Ruturaj Gaikwad      1
# Rashid Khan          1
# Suruakumar Yadav     1
# Anuj Rawat           1
# Odean Smith          1
# Mohammed Shami       1
# ...

# %%
#top 10 players with hieghtest man of the match award
data['player_of_the_match'].value_counts()[0:10]
# Out:
# player_of_the_match
# Kuldeep Yadav      4
# Jos Buttler        3
# Umesh Yadav        2
# Quinton de Kock    2
# David Miller       2
# Umran Malik        2
# K L Rahul          2
# Rahul Tripathi     2
# Hardik Pandya      2
# Jasprit Bumrah     2
# Name: count, dtype: int64

# %%
#Bar chart of top 10 player of the match
plt.figure(figsize =(15,4))
plt.bar(data['player_of_the_match'].value_counts()[0:10].keys(),data['player_of_the_match'].value_counts()[0:10])
# Out:
# <BarContainer object of 10 artists>

# %%
# checking which team won the most toss
data['toss_winner'].value_counts()
# Out:
# toss_winner
# Gujarat      10
# Hyderabad    10
# Mumbai        9
# Kolkata       8
# Delhi         8
# Banglore      8
# Lucknow       7
# Chennai       6
# Punjab        4
# Rajasthan     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(data['toss_winner'].value_counts(), labels=toss_counts.keys(), autopct='%1.1f%%')
plt.title('Toss Wins by Teams')
# Out:
# Text(0.5, 1.0, 'Toss Wins by Teams')

# %%
#Count how many times each team chose to bat or field after winning the toss
data.groupby(['toss_winner', 'toss_decision']).size().unstack(fill_value=0)
# Out:
# toss_decision  Bat  Field
# toss_winner
# Banglore         2      6
# Chennai          2      4
# Delhi            0      8
# Gujarat          4      6
# Hyderabad        1      9
# Kolkata          1      7
# Lucknow          2      5
# Mumbai           0      9
# Punjab           1      3
# Rajasthan        2      2

# %%
#bar Chart to show Count how many times each team chose to bat or field after winning the toss
grouped.plot(kind='bar', figsize=(10,6))
plt.title('Toss Decision by Toss-Winning Teams')
plt.xlabel('Team')
plt.ylabel('Number of Times')
plt.xticks(rotation= 0)
plt.legend(title='Toss Decision')

# %%
# Number of matches won by each team
data['match_winner'].value_counts()
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Delhi         7
# Punjab        7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
# Number of matches won by each team in doughnut chart
plt.pie(data['match_winner'].value_counts(), labels=data['match_winner'].value_counts().keys(),autopct='%1.1f%%',radius=2)
plt.pie([1],colors=['White'],radius=0.8)
# Out:
# ([<matplotlib.patches.Wedge at 0x2bfed707b50>],
#  [Text(-0.8800000000000001, 1.077689183249671e-16, '')])

# %%
#Plotting a histogram to visualize how frequently different first innings score 
sns.histplot(data['first_ings_score'],kde = True, bins =12)
# Out:
# <Axes: xlabel='first_ings_score', ylabel='Count'>

# %%
#average score in first innings 
np.mean(data['first_ings_score'])
# Out:
# 171.1216216216216

# %%
#Higest score in first innings 
np.max(data['first_ings_score'])
# Out:
# 222

# %%
#lowest score in first innings 
np.min(data['first_ings_score'])
# Out:
# 68

# %%
#which team made the highest score
max_index = np.argmax(data['first_ings_score'].values)
data['team1'].values[max_index]
# Out:
# 'Delhi'

# %%
# for 2nd inings
np.mean(data['second_ings_score'])
# Out:
# 158.54054054054055

# %%
np.max(data['second_ings_score'])
# Out:
# 211

# %%
np.min(data['second_ings_score'])
# Out:
# 72

# %%
max_index = np.argmax(data['second_ings_score'].values)
data['team1'].values[max_index]
# Out:
# 'Chennai'

# %%
#Plotting a histogram to visualize how frequently different first innings score 
sns.distplot(data['second_ings_score'], bins =12)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25656\3601540335.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['second_ings_score'], bins =12)
# <Axes: xlabel='second_ings_score', ylabel='Density'>

# %%
#whether the team that won the toss also won the match.
np.sum(data['toss_winner'] == data['match_winner'])
# Out:
# 36

# %%
# in percentage
36/74
# Out:
# 0.4864864864864865

# %%
#Heatmap of Team vs Team Wins
sns.heatmap(pd.crosstab(data['team1'], data['team2']), cmap='Blues', annot=True)
# Out:
# <Axes: xlabel='team2', ylabel='team1'>

# %%
#matches were won (by Wickets or Runs)
sns.countplot(data=data, x='won_by')
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %%
#Visualization for margin distribution
sns.histplot(data['margin'], kde=True)
# Out:
# <Axes: xlabel='margin', ylabel='Count'>

# %%
#top 10 best bowling performances
plt.figure(figsize =(16,5))
top_bowling = data['best_bowling'].value_counts()[0:10]
sns.barplot(x=top_bowling.index, y=top_bowling.values, palette='viridis')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25656\3114161429.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_bowling.index, y=top_bowling.values, palette='viridis')
# <Axes: xlabel='best_bowling'>

# %%
#top 10 top scorers
plt.figure(figsize =(16,5))
top_scorers = data['top_scorer'].value_counts().head(10)
sns.barplot(x=top_scorers.index, y=top_scorers.values, palette='plasma' )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25656\2504701786.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_scorers.index, y=top_scorers.values, palette='plasma' )
# <Axes: xlabel='top_scorer'>

# %%
# Count of top winner teams by venue
plt.figure(figsize=(25, 6))
sns.countplot(data=data, x='venue', hue='match_winner', palette='Set2')
# Out:
# <Axes: xlabel='venue', ylabel='count'>

# %%
#Total Runs Scored in the First vs Second Innings
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[['first_ings_score', 'second_ings_score']], palette='pastel')
# Out:
# <Axes: >
